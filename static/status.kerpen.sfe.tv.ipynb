# %% [markdown]
# ### info

# %%
cd ~/proj/interactive.here.d/
# Out:
# /home/rogera/proj/interactive.here.d

# %% [markdown]
# .here: http://ipy.wolfspool.chickenkiller.com:18888/c20a2a88-eb98-407f-acce-939c857e924c#

# %%
# %%bash
# date
# ssh elias@kerpen.sfe.tv sudo docker ps -a
# Out:
# Fre Feb 27 20:39:52 CET 2015
# CONTAINER ID        IMAGE                                              COMMAND                CREATED             STATUS                      PORTS                    NAMES
# dea7727fbd71        wolfhesse/r20150227.t1:t0021                       "forever /srv/comman   20 hours ago        Up 19 hours                 0.0.0.0:4000->4000/tcp   r2
# dff363a515e3        trickkiste/docker-stackbrew-melted-custom:latest   "melted -c /etc/melt   3 months ago        Up 2 days                                            melted
# 1608a301cf74        trickkiste/dispatcher:0.2                          "forever /srv/comman   3 months ago        Exited (143) 36 hours ago                            type1tv-dispatcher
# 473a583fac89        trickkiste/stackbrew-melted-nodetach:latest        "melted -c /etc/melt   10 months ago       Exited (-1) 10 months ago                            melted-server

# %%
# %%bash
# date
# ssh elias@kerpen.sfe.tv sudo docker images
# Out:
# Fre Feb 27 20:39:53 CET 2015
# REPOSITORY                                  TAG                 IMAGE ID            CREATED             VIRTUAL SIZE
# wolfhesse/r20150227.t1                      t0021               1d29363fc564        20 hours ago        397.6 MB
# wolfhesse/r20150226.t1                      latest              0f97c5bbf6c6        37 hours ago        398.1 MB
# wolfhesse/r20150217.t1                      latest              562edbac188c        9 days ago          396.8 MB
# busybox                                     buildroot-2014.02   4986bf8c1536        8 weeks ago         2.433 MB
# busybox                                     latest              4986bf8c1536        8 weeks ago         2.433 MB
# trickkiste/dispatcher                       0.2                 f8a6b89a3d2a        7 months ago        344.6 MB
# trickkiste/docker-stackbrew-melted-custom   latest              02142f1b7fbc        7 months ago        2.546 GB
# ...

# %%
# %%bash
# date
# #ssh elias@kerpen.sfe.tv ls -xR /srv/elias/assets
# ssh elias@kerpen.sfe.tv find /srv/elias/assets/videos -print
# Out:
# Fre Feb 27 20:39:54 CET 2015
# /srv/elias/assets/videos
# /srv/elias/assets/videos/atlas2_guillo_0.mov
# /srv/elias/assets/videos/cb_plinkflojd_lazinginthehaze_peverett_G.mov
# /srv/elias/assets/videos/fantasticspins5_lernertsander_0.mov
# /srv/elias/assets/videos/p18el4obqrr38r021ihp1nke2k33_HP_1801A1.m4v
# /srv/elias/assets/videos/p186kmkk661mkt13c91icr72ild85_test_20131110FTPp_G.mov
# /srv/elias/assets/videos/03_Skip_Arnold_-_action_5_0.mov
# /srv/elias/assets/videos/outofherefull_moya_F.mov
# /srv/elias/assets/videos/p18qau91jt1l2hgns105fnfs192t3_OTG-DIANE_PERNET_130614.mov
# /srv/elias/assets/videos/baumeister_larcher_F.mov
# /srv/elias/assets/videos/p18enqtd2l1gi01m6u1moheonfc34_VVV_ombre.mov
# /srv/elias/assets/videos/cb_cloaque_F.mov
# /srv/elias/assets/videos/p19cbvhgho5e91j1luj58r155n3_OTG_PUB_FRNACOISC_23.01.15_HD-ALTERPOP_HD_sans_fade.mov
# /srv/elias/assets/videos/p17q6tnni6uni45f1mf6137m1fqu3_riciotti.mov
# ...
